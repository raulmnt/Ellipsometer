# %%
import numpy as np
import pandas as pd
import tmm

# imports and setup for tmm
from __future__ import division, print_function, absolute_import

from tmm import (coh_tmm, unpolarized_RT, ellips,
                       position_resolved, find_in_structure_with_inf)

from numpy import pi, linspace, inf, array
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
# %matplotlib inline


# "5 * degree" is 5 degrees expressed in radians
# "1.2 / degree" is 1.2 radians expressed in degrees
degree = pi/180

# %%
# Read the raw data file, skip the first three rows without a header and select the following 51 rows
raw_data = pd.read_csv('25 nm of SiO2.dat', sep = '\t', skiprows= 4, header=None)
#Rename the columns of the raw data frame into relevant features
raw_data.columns = ['lambda_vac', 'th_0', 'psi_exp', 'delta_exp', 'psi_exp_sigma', 'delta_exp_sigma']

# %%
raw_data
# Out:
#      lambda_vac  th_0    psi_exp   delta_exp  psi_exp_sigma  delta_exp_sigma
# 0         300.0  65.0  37.470924  108.225250       0.299714         0.653519
# 1         310.0  65.0  36.357937  107.988220       0.250304         0.550787
# 2         320.0  65.0  35.595108  109.826470       0.258704         0.580831
# 3         330.0  65.0  35.136696  111.131290       0.377628         0.859414
# 4         340.0  65.0  34.184349  112.822850       0.809246         1.887950
# ..          ...   ...        ...         ...            ...              ...
# 97        760.0  75.0  10.963696   78.241798       0.008063         0.044102
# 98        770.0  75.0  10.820502   78.041321       0.008454         0.046847
# 99        780.0  75.0  10.675869   77.787621       0.009062         0.050886
# 100       790.0  75.0  10.528711   77.541664       0.008666         0.049326
# 101       800.0  75.0  10.388067   77.278450       0.008742         0.050410
#
# [102 rows x 6 columns]

# %%
#silicon Jaw2 nk data
Si_nk_data = array([[300,5.084+4.247j],
[310,5.123+3.645j],
[320,5.147+3.331j],
[330,5.216+3.134j],
[340,5.336+3.008j],
[350,5.539+2.960j],
[360,6.088+2.978j],
[370,6.984+2.129j],
[380,6.676+0.888j],
[390,6.072+0.460j],
[400,5.674+0.279j],
[410,5.371+0.177j],
[420,5.132+0.124j],
[430,4.945+0.097j],
[440,4.796+0.083j],
[450,4.676+0.075j],
[460,4.576+0.068j],
[470,4.491+0.062j],
[480,4.417+0.056j],
[490,4.352+0.052j],
[500,4.294+0.048j],
[510,4.243+0.044j],
[520,4.196+0.041j],
[530,4.154+0.038j],
[540,4.116+0.035j],
[550,4.081+0.032j],
[560,4.049+0.030j],
[570,4.020+0.028j],
[580,3.993+0.026j],
[590,3.968+0.024j],
[600,3.944+0.023j],
[610,3.923+0.021j],
[620,3.902+0.020j],
[630,3.883+0.019j],
[640,3.865+0.017j],
[650,3.849+0.016j],
[660,3.833+0.015j],
[670,3.818+0.014j],
[680,3.804+0.013j],
[690,3.791+0.012j],
[700,3.778+0.011j],
[710,3.766+0.010j],
[720,3.755+0.010j],
[730,3.744+0.009j],
[740,3.734+0.008j],
[750,3.724+0.008j],
[760,3.715+0.007j],
[770,3.706+0.007j],
[780,3.698+0.006j],
[790,3.690+0.006j],
[800,3.682+0.005j],
[810,3.675+0.005j],
[820,3.668+0.004j],
[830,3.661+0.004j],
[840,3.654+0.004j],
[850,3.648+0.003j],
[860,3.642+0.003j],
[870,3.636+0.003j],
[880,3.631+0.002j],
[890,3.625+0.002j],
[900,3.620+0.002j],
[910,3.615+0.002j],
[920,3.611+0.002j],
[930,3.606+0.001j],
[940,3.602+0.001j],
[950,3.597+0.001j],
[960,3.593+0.001j],
[970,3.589+0.001j],
[980,3.585+0.001j],
[990,3.582+0.001j],
[1000,3.578+0.000j]])

# %%
#silicon dioxide Jaw2 nk data
SiO2_nk_data = array([[300,1.493],
[310,1.490],
[320,1.488],
[330,1.486],
[340,1.484],
[350,1.482],
[360,1.481],
[370,1.479],
[380,1.478],
[390,1.477],
[400,1.475],
[410,1.474],
[420,1.473],
[430,1.472],
[440,1.472],
[450,1.471],
[460,1.470],
[470,1.469],
[480,1.469],
[490,1.468],
[500,1.468],
[510,1.467],
[520,1.467],
[530,1.466],
[540,1.466],
[550,1.465],
[560,1.465],
[570,1.464],
[580,1.464],
[590,1.464],
[600,1.463],
[610,1.463],
[620,1.463],
[630,1.462],
[640,1.462],
[650,1.462],
[660,1.462],
[670,1.461],
[680,1.461],
[690,1.461],
[700,1.461],
[710,1.461],
[720,1.460],
[730,1.460],
[740,1.460],
[750,1.460],
[760,1.460],
[770,1.459],
[780,1.459],
[790,1.459],
[800,1.459],
[810,1.459],
[820,1.459],
[830,1.458],
[840,1.458],
[850,1.458],
[860,1.458],
[870,1.458],
[880,1.458],
[890,1.458],
[900,1.457],
[910,1.457],
[920,1.457],
[930,1.457],
[940,1.457],
[950,1.457],
[960,1.457],
[970,1.457],
[980,1.456],
[990,1.456],
[1000,1.456]])

# %%
Si_nk_fn = interp1d(Si_nk_data[:,0].real,
                          Si_nk_data[:,1], kind='quadratic')
SiO2_nk_fn = interp1d(SiO2_nk_data[:,0].real,
                          SiO2_nk_data[:,1], kind='quadratic')

# %%
import math

def nk_cauchy(A,B,C,alpha, beta, gamma, lambda_vac):
    
#the values are entered in nm
    
    #convert to um
    lambda_vac_um=lambda_vac/1000
    gamma_um=gamma/1000
    
    #calculate n
    n_cauchy=A+B/(lambda_vac_um)**2+C/(lambda_vac_um)**4
    
    #calculate k
    k_cauchy=alpha*math.exp(beta*(1.24*((1/lambda_vac_um)-(1/gamma_um))))
    
    #return complex refractive index
    return complex(n_cauchy, k_cauchy);

# %%
def MSE(params):
    
    #set the known parameters. 
    alpha=0
    beta=0
    gamma=400
    thickness,A,B,C= params
    
    #set number of layers and thickness
    d_list = [inf,thickness,inf] #in nm
    
    # calculate psi and delta from the model 
    psi_mod=[]
    delta_mod=[]
    for _, row in raw_data.iterrows():
                n_list = [1,nk_cauchy(A,B,C,alpha, beta, gamma, row['lambda_vac']),Si_nk_fn(row['lambda_vac'])]
                e_data=ellips(n_list, d_list, row['th_0']*degree, row['lambda_vac']) #in nm
                psi_mod.append(e_data['psi']/degree) # angle in degrees
                delta_mod.append((pi-e_data['Delta'])/degree) # angle in degrees
    # make a dataframe with the values from the model
    
    raw_data['psi_mod'] = psi_mod
    raw_data['delta_mod'] = delta_mod
    
    # calculate MSE
    xi=((raw_data['psi_mod'] - raw_data['psi_exp'])/(raw_data['psi_exp_sigma']))**2+((raw_data['delta_mod'] - raw_data['delta_exp'])/(raw_data['delta_exp_sigma']))**2
    MSE_calc=(xi.sum(axis=0)/(2*len(xi)-1))**(1/2)

    return MSE_calc

# %%
# %%time
import scipy.optimize as optimize

#set initial parameters to start the optimization
initial_guess = [24, 1.5,0,0]

# set bound values for each parameter to be fitted
bounds = [(0,50), (1,3),(0,.5),(0,.5)]

#set parameters for optimization
result = optimize.minimize(MSE, initial_guess,bounds = bounds)

if result.success:
    fitted_params_local = result.x
    print('Fitted parameters:')
    print('thickness =',fitted_params_local[0])
    print('A=',fitted_params_local[1])
    print('MSE=', result.fun)
else:
    raise ValueError(result.message)
# Out:
# Fitted parameters:
# thickness = 24.032687235150714
# A= 1.5239686097320542
# MSE= 5.360995099228773
# CPU times: user 5.73 s, sys: 30.5 ms, total: 5.76 s
# Wall time: 5.76 s

# %%
# %%time
#use diferential evolution to find the global minimum
from scipy.optimize import differential_evolution

#set the bounds of the parameters to be fitted
bounds = [(0,50), (1,3),(0,.5),(0,.5)]

#set parameters for the model
result=differential_evolution(MSE, bounds, args=(), 
                                      strategy='best1bin', maxiter=100, popsize=10, tol=0.01, 
                                      mutation=(0.5, 1), recombination=0.7, seed=None, callback=None, 
                                      disp=True, polish=True, init='latinhypercube', atol=0, 
                                     updating='immediate', workers=1, constraints=())

fitted_params = result.x
print('Fitted parameters:')
print('thickness =',fitted_params[0])
print('A=',fitted_params[1])
print('B=',fitted_params[2])
print('C=',fitted_params[3])
print('MSE=', result.fun)
# Out:
# differential_evolution step 1: f(x)= 248.077
# differential_evolution step 2: f(x)= 248.077
# differential_evolution step 3: f(x)= 248.077
# differential_evolution step 4: f(x)= 148.502
# differential_evolution step 5: f(x)= 148.502
# differential_evolution step 6: f(x)= 148.502
# differential_evolution step 7: f(x)= 148.502
# differential_evolution step 8: f(x)= 143.325
# differential_evolution step 9: f(x)= 38.3971
# differential_evolution step 10: f(x)= 38.3971
# differential_evolution step 11: f(x)= 38.3971
# differential_evolution step 12: f(x)= 38.3971
# differential_evolution step 13: f(x)= 38.3971
# differential_evolution step 14: f(x)= 38.3971
# differential_evolution step 15: f(x)= 15.0958
# differential_evolution step 16: f(x)= 15.0958
# differential_evolution step 17: f(x)= 15.0958
# differential_evolution step 18: f(x)= 13.0403
# differential_evolution step 19: f(x)= 13.0403
# differential_evolution step 20: f(x)= 13.0403
# differential_evolution step 21: f(x)= 13.0403
# differential_evolution step 22: f(x)= 12.2512
# differential_evolution step 23: f(x)= 12.2512
# differential_evolution step 24: f(x)= 12.2512
# differential_evolution step 25: f(x)= 12.2512
# differential_evolution step 26: f(x)= 12.2512
# differential_evolution step 27: f(x)= 12.2512
# differential_evolution step 28: f(x)= 12.2512
# differential_evolution step 29: f(x)= 9.91325
# differential_evolution step 30: f(x)= 7.78905
# differential_evolution step 31: f(x)= 7.78905
# differential_evolution step 32: f(x)= 7.77959
# differential_evolution step 33: f(x)= 7.19445
# differential_evolution step 34: f(x)= 7.19445
# differential_evolution step 35: f(x)= 6.23011
# differential_evolution step 36: f(x)= 6.23011
# differential_evolution step 37: f(x)= 6.23011
# differential_evolution step 38: f(x)= 6.23011
# differential_evolution step 39: f(x)= 6.23011
# differential_evolution step 40: f(x)= 6.21831
# differential_evolution step 41: f(x)= 6.21831
# differential_evolution step 42: f(x)= 6.08498
# differential_evolution step 43: f(x)= 5.71311
# differential_evolution step 44: f(x)= 5.71311
# differential_evolution step 45: f(x)= 5.71311
# differential_evolution step 46: f(x)= 5.50333
# differential_evolution step 47: f(x)= 5.46865
# differential_evolution step 48: f(x)= 5.44529
# differential_evolution step 49: f(x)= 5.44529
# differential_evolution step 50: f(x)= 5.41443
# differential_evolution step 51: f(x)= 5.41443
# differential_evolution step 52: f(x)= 5.41443
# differential_evolution step 53: f(x)= 5.41443
# differential_evolution step 54: f(x)= 5.41443
# differential_evolution step 55: f(x)= 5.41443
# differential_evolution step 56: f(x)= 5.41443
# differential_evolution step 57: f(x)= 5.41374
# differential_evolution step 58: f(x)= 5.41374
# differential_evolution step 59: f(x)= 5.39552
# differential_evolution step 60: f(x)= 5.37498
# differential_evolution step 61: f(x)= 5.37498
# differential_evolution step 62: f(x)= 5.37498
# differential_evolution step 63: f(x)= 5.37192
# differential_evolution step 64: f(x)= 5.37192
# differential_evolution step 65: f(x)= 5.37192
# differential_evolution step 66: f(x)= 5.36828
# Fitted parameters:
# thickness = 24.04552854851093
# A= 1.5233815229559127
# B= 0.0
# C= 0.0
# MSE= 5.361954924234276
# CPU times: user 1min 31s, sys: 1.39 s, total: 1min 32s
# Wall time: 1min 30s
